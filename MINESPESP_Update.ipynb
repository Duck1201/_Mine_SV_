# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'vanilla'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://api.serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://api.serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://api.serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://api.serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /workspaces/codespaces-jupyter/Minecraft-server
# Unpacking 1.20.2/server-1.20.2.jar (versions:1.20.2) to versions/1.20.2/server-1.20.2.jar
# Unpacking com/github/oshi/oshi-core/6.4.5/oshi-core-6.4.5.jar (libraries:com.github.oshi:oshi-core:6.4.5) to libraries/com/github/oshi/oshi-core/6.4.5/oshi-core-6.4.5.jar
# Unpacking com/google/code/gson/gson/2.10.1/gson-2.10.1.jar (libraries:com.google.code.gson:gson:2.10.1) to libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
# Unpacking com/google/guava/failureaccess/1.0.1/failureaccess-1.0.1.jar (libraries:com.google.guava:failureaccess:1.0.1) to libraries/com/google/guava/failureaccess/1.0.1/failureaccess-1.0.1.jar
# Unpacking com/google/guava/guava/32.1.2-jre/guava-32.1.2-jre.jar (libraries:com.google.guava:guava:32.1.2-jre) to libraries/com/google/guava/guava/32.1.2-jre/guava-32.1.2-jre.jar
# Unpacking com/mojang/authlib/5.0.47/authlib-5.0.47.jar (libraries:com.mojang:authlib:5.0.47) to libraries/com/mojang/authlib/5.0.47/authlib-5.0.47.jar
# Unpacking com/mojang/brigadier/1.1.8/brigadier-1.1.8.jar (libraries:com.mojang:brigadier:1.1.8) to libraries/com/mojang/brigadier/1.1.8/brigadier-1.1.8.jar
# Unpacking com/mojang/datafixerupper/6.0.8/datafixerupper-6.0.8.jar (libraries:com.mojang:datafixerupper:6.0.8) to libraries/com/mojang/datafixerupper/6.0.8/datafixerupper-6.0.8.jar
# Unpacking com/mojang/logging/1.1.1/logging-1.1.1.jar (libraries:com.mojang:logging:1.1.1) to libraries/com/mojang/logging/1.1.1/logging-1.1.1.jar
# Unpacking commons-io/commons-io/2.13.0/commons-io-2.13.0.jar (libraries:commons-io:commons-io:2.13.0) to libraries/commons-io/commons-io/2.13.0/commons-io-2.13.0.jar
# Unpacking io/netty/netty-buffer/4.1.97.Final/netty-buffer-4.1.97.Final.jar (libraries:io.netty:netty-buffer:4.1.97.Final) to libraries/io/netty/netty-buffer/4.1.97.Final/netty-buffer-4.1.97.Final.jar
# Unpacking io/netty/netty-codec/4.1.97.Final/netty-codec-4.1.97.Final.jar (libraries:io.netty:netty-codec:4.1.97.Final) to libraries/io/netty/netty-codec/4.1.97.Final/netty-codec-4.1.97.Final.jar
# Unpacking io/netty/netty-common/4.1.97.Final/netty-common-4.1.97.Final.jar (libraries:io.netty:netty-common:4.1.97.Final) to libraries/io/netty/netty-common/4.1.97.Final/netty-common-4.1.97.Final.jar
# Unpacking io/netty/netty-handler/4.1.97.Final/netty-handler-4.1.97.Final.jar (libraries:io.netty:netty-handler:4.1.97.Final) to libraries/io/netty/netty-handler/4.1.97.Final/netty-handler-4.1.97.Final.jar
# Unpacking io/netty/netty-resolver/4.1.97.Final/netty-resolver-4.1.97.Final.jar (libraries:io.netty:netty-resolver:4.1.97.Final) to libraries/io/netty/netty-resolver/4.1.97.Final/netty-resolver-4.1.97.Final.jar
# Unpacking io/netty/netty-transport/4.1.97.Final/netty-transport-4.1.97.Final.jar (libraries:io.netty:netty-transport:4.1.97.Final) to libraries/io/netty/netty-transport/4.1.97.Final/netty-transport-4.1.97.Final.jar
# Unpacking io/netty/netty-transport-classes-epoll/4.1.97.Final/netty-transport-classes-epoll-4.1.97.Final.jar (libraries:io.netty:netty-transport-classes-epoll:4.1.97.Final) to libraries/io/netty/netty-transport-classes-epoll/4.1.97.Final/netty-transport-classes-epoll-4.1.97.Final.jar
# Unpacking io/netty/netty-transport-native-epoll/4.1.97.Final/netty-transport-native-epoll-4.1.97.Final-linux-x86_64.jar (libraries:io.netty:netty-transport-native-epoll:4.1.97.Final:linux-x86_64) to libraries/io/netty/netty-transport-native-epoll/4.1.97.Final/netty-transport-native-epoll-4.1.97.Final-linux-x86_64.jar
# Unpacking io/netty/netty-transport-native-epoll/4.1.97.Final/netty-transport-native-epoll-4.1.97.Final-linux-aarch_64.jar (libraries:io.netty:netty-transport-native-epoll:4.1.97.Final:linux-aarch_64) to libraries/io/netty/netty-transport-native-epoll/4.1.97.Final/netty-transport-native-epoll-4.1.97.Final-linux-aarch_64.jar
# Unpacking io/netty/netty-transport-native-unix-common/4.1.97.Final/netty-transport-native-unix-common-4.1.97.Final.jar (libraries:io.netty:netty-transport-native-unix-common:4.1.97.Final) to libraries/io/netty/netty-transport-native-unix-common/4.1.97.Final/netty-transport-native-unix-common-4.1.97.Final.jar
# Unpacking it/unimi/dsi/fastutil/8.5.12/fastutil-8.5.12.jar (libraries:it.unimi.dsi:fastutil:8.5.12) to libraries/it/unimi/dsi/fastutil/8.5.12/fastutil-8.5.12.jar
# Unpacking net/java/dev/jna/jna/5.13.0/jna-5.13.0.jar (libraries:net.java.dev.jna:jna:5.13.0) to libraries/net/java/dev/jna/jna/5.13.0/jna-5.13.0.jar
# Unpacking net/java/dev/jna/jna-platform/5.13.0/jna-platform-5.13.0.jar (libraries:net.java.dev.jna:jna-platform:5.13.0) to libraries/net/java/dev/jna/jna-platform/5.13.0/jna-platform-5.13.0.jar
# Unpacking net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar (libraries:net.sf.jopt-simple:jopt-simple:5.0.4) to libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
# Unpacking org/apache/commons/commons-lang3/3.13.0/commons-lang3-3.13.0.jar (libraries:org.apache.commons:commons-lang3:3.13.0) to libraries/org/apache/commons/commons-lang3/3.13.0/commons-lang3-3.13.0.jar
# Unpacking org/apache/logging/log4j/log4j-api/2.19.0/log4j-api-2.19.0.jar (libraries:org.apache.logging.log4j:log4j-api:2.19.0) to libraries/org/apache/logging/log4j/log4j-api/2.19.0/log4j-api-2.19.0.jar
# Unpacking org/apache/logging/log4j/log4j-core/2.19.0/log4j-core-2.19.0.jar (libraries:org.apache.logging.log4j:log4j-core:2.19.0) to libraries/org/apache/logging/log4j/log4j-core/2.19.0/log4j-core-2.19.0.jar
# Unpacking org/apache/logging/log4j/log4j-slf4j2-impl/2.19.0/log4j-slf4j2-impl-2.19.0.jar (libraries:org.apache.logging.log4j:log4j-slf4j2-impl:2.19.0) to libraries/org/apache/logging/log4j/log4j-slf4j2-impl/2.19.0/log4j-slf4j2-impl-2.19.0.jar
# Unpacking org/joml/joml/1.10.5/joml-1.10.5.jar (libraries:org.joml:joml:1.10.5) to libraries/org/joml/joml/1.10.5/joml-1.10.5.jar
# Unpacking org/slf4j/slf4j-api/2.0.7/slf4j-api-2.0.7.jar (libraries:org.slf4j:slf4j-api:2.0.7) to libraries/org/slf4j/slf4j-api/2.0.7/slf4j-api-2.0.7.jar
# Starting net.minecraft.server.Main
# [18:56:24] [ServerMain/ERROR]: Failed to start the minecraft server
# joptsimple.UnrecognizedOptionException: installServer is not a recognized option
# 	at joptsimple.OptionException.unrecognizedOption(OptionException.java:108) ~[jopt-simple-5.0.4.jar:?]
# 	at joptsimple.OptionParser.handleLongOptionToken(OptionParser.java:510) ~[jopt-simple-5.0.4.jar:?]
# 	at joptsimple.OptionParserState$2.handleArgument(OptionParserState.java:56) ~[jopt-simple-5.0.4.jar:?]
# 	at joptsimple.OptionParser.parse(OptionParser.java:396) ~[jopt-simple-5.0.4.jar:?]
# 	at net.minecraft.server.Main.main(SourceFile:87) ~[server-1.20.2.jar:?]
# 	at net.minecraft.bundler.Main.lambda$run$0(Main.java:54) ~[?:?]
# 	at java.lang.Thread.run(Thread.java:1583) ~[?:?]
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms12G -Xmx12G"

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt		  mohist-config      usernamecache.json
# banned-players.json  help.yml		  ops.json	     vanilla.jar
# bukkit.yml	     hs_err_pid13655.log  permissions.yml    whitelist.json
# colabconfig.json     journeymap		  plugins	     world
# commands.yml	     libraries		  server.properties
# config		     logs		  spigot.yml
# defaultconfigs	     mods		  usercache.json
# Estas jugando a minecraft: vanilla en su version: 1.20.2
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#
#  __    __   ______   __  __   __   ______   ______
# /\ "-./  \ /\  __ \ /\ \_\ \ /\ \ /\  ___\ /\__  _\
# \ \ \-./\ \\ \ \/\ \\ \  __ \\ \ \\ \___  \\/_/\ \/
#  \ \_\ \ \_\\ \_____\\ \_\ \_\\ \_\\/\_____\  \ \_\
#   \/_/  \/_/ \/_____/ \/_/\/_/ \/_/ \/_____/   \/_/
#
#
# Welcome to Mohist 1.16.5 ! - Mohist Developement Group - 1.16.5-1239, Java 61.0
# Checking libraries, please wait...
# DownloadSource: MOHIST
# All libraries are nice :) !
# Checking the installation, please wait.
# Finished the install verification process !
# [23:38:40 INFO]: ModLauncher running: args [--gameDir, ., --launchTarget, fmlserver, --fml.mohistVersion, 1239, --fml.forgeVersion, 36.2.42, --fml.mcpVersion, 20210115.111550, --fml.mcVersion, 1.16.5, --fml.forgeGroup, com.mohistmc, nogui]
# [23:38:40 INFO]: ModLauncher mohist-8.1.3 starting: java version 17.0.9 by Amazon.com Inc.
# [23:38:40 INFO]: Added Lets Encrypt root certificates as additional trust
# [23:38:40 INFO]: SpongePowered MIXIN Subsystem Version=0.8.4 Source=file:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.4/mixin-0.8.4.jar Service=ModLauncher Env=SERVER
# Init CreativeCore coremods ...
# [23:38:42 INFO]: Launching target 'fmlserver' with arguments [--gameDir, ., nogui]
# [23:38:42 WARN]: Reference map 'nethers_delight.refmap.json' for nethers_delight.mixins.json could not be read. If this is a development environment you can ignore this message
# [Serene Seasons Transformer]: Transforming func_176224_k in net/minecraft/block/CauldronBlock
# [Serene Seasons Transformer]: Patched 1 calls
# [23:38:43 WARN]: Error loading class: com/ferreusveritas/dynamictrees/worldgen/BiomeRadiusCoordinator (java.lang.ClassNotFoundException: null)
# [23:38:43 WARN]: Error loading class: com/ferreusveritas/dynamictrees/worldgen/TreeGenerator (java.lang.ClassNotFoundException: null)
# [Serene Seasons Transformer]: Transforming func_201854_a in net/minecraft/world/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming func_201850_b in net/minecraft/world/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming func_201854_a in net/minecraft/world/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming func_201850_b in net/minecraft/world/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming func_176224_k in net/minecraft/block/CauldronBlock
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming func_70636_d in net/minecraft/entity/passive/SnowGolemEntity
# [Serene Seasons Transformer]: Patched 2 calls
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `citadel` for name `debug`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `citadel` for name `citadel_book`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `citadel` for name `effect_item`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `citadel` for name `fancy_item`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `rats` for name `synesthesia`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:51 INFO]: Potentially Dangerous alternative prefix `rats` for name `plague`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [23:38:52 INFO]: Starting extraction of Skylands
# [23:38:52 INFO]: Preset Skylands was already up to date, skipped
# [23:38:53 INFO]: Detected new forge version, registering events reflectively.
# [23:38:55 INFO]: Forge mod loading, version 36.2.42, for MC 1.16.5 with MCP 20210115.111550
# [23:38:55 INFO]: MinecraftForge v36.2.42 Initialized
# [23:38:55 INFO]: EventDispatcherRegistry initialized
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 WARN]: unable to set craftingRemainingItem for upgrade item
# [23:39:07 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `shulker_shell`, expected `supplementaries`. This could be a intended override, but in most cases indicates a broken mod.
# [23:39:07 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `otg`, expected `otg`. This could be a intended override, but in most cases indicates a broken mod.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_spawner, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:pied_piper, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:plague_doctor, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:black_death, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:plague_cloud, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:plague_beast, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_mount_chicken, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_mount_beast, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_king, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:demon_rat, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_mount_strider, use EntityAttributeCreationEvent instead.
# [23:39:08 WARN]: Called deprecated GlobalEntityTypeAttributes#put for rats:rat_mount_golem, use EntityAttributeCreationEvent instead.
# [23:39:08 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [23:39:08 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `flowing_milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [23:39:11 INFO]: [voicechat] Compatibility version 18
# [23:39:11 INFO]: [voicechat] Loading plugins
# [23:39:11 INFO]: [voicechat] Loaded 0 plugin(s)
# [23:39:11 INFO]: [voicechat] Initializing plugins
# [23:39:11 INFO]: [voicechat] Initialized 0 plugin(s)
# [23:39:11 INFO]: Initializing Packet Registries
# [23:39:12 INFO]: [com.mrh0.buildersaddition.BuildersAddition:postInit:80]: Builders Addition Initialized!
# [23:39:24 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [23:39:25 INFO]: Reloading ResourceManager: Default, mcw-bridges-2.0.7-mc1.16.5forge.jar, FarmersDelight-1.16.5-0.6.0.jar, grappling_hook_mod-1.16.5-v13.jar, TreeChop-1.16.4-0.14.6-fixed.jar, SkyVillage_1.0.0_1.16.5.jar, AmbientSounds_v3.1.11_mc1.16.5.jar, BiomesOPlenty-1.16.5-13.1.0.477-universal.jar, CreativeCore_v2.2.1_mc1.16.5.jar, cavesandcliffs-1.16.5-7.2.0.jar, abnormals_core-1.16.5-3.3.1.jar, mcw-windows-2.1.1-mc1.16.5forge.jar, torohealth-1.16.4-forge-4.jar, flywheel-1.16-0.2.5.jar, create-mc1.16.5_v0.3.2g.jar, Waystones_1.16.5-7.6.4.jar, OTG-Skylands-1.16.5-v6.jar, shutupexperimentalsettings-1.0.3.jar, citadel-1.8.1-1.16.5.jar, alexsmobs-1.12.1.jar, rats-7.2.0-1.16.5.jar, ParCool-1.16.5-3.0.1.0-R.jar, NaturesCompass-1.16.5-1.9.1-forge.jar, SereneSeasons-1.16.5-4.0.1.130-universal.jar, OpenTerrainGenerator-1.16.5-0.1.10.jar, buildersaddition-1.16.5-20210807a.jar, sophisticatedbackpacks-1.16.5-3.15.20.755.jar, cavebiomeapi-1.16.5-1.4.2.jar, nethers_delight-2.1.jar, iceandfire-2.1.12-1.16.5.jar, cloth-config-4.16.91-forge.jar, mohist-1.16.5-1239-universal.jar, appleskin-forge-mc1.16.x-2.4.0.jar, dummmmmmy-1.16.5-1.3.3.jar, supplementaries-1.16.5-0.18.5.jar, DynamicSurroundings-1.16.5-4.0.5.0.jar, selene-1.16.5-1.9.0.jar, voicechat-forge-1.16.5-2.5.12.jar, jei-1.16.5-7.7.1.153.jar, journeymap-1.16.5-5.8.5p6.jar, bukkit, [1.16.5] SecurityCraft v1.9.8.jar
# [23:39:27 INFO]: Loot Modification Manager has loaded 0 sets of modifiers
# [23:39:27 INFO]: Advancement Modification Manager has loaded 0 sets of modifiers
# [23:39:30 WARN]: Found validation problem in {alexsmobs:gameplay/seal_reward}.pools[0].entries[1].functions[0]: Parameters [<parameter minecraft:origin>] are not provided in this context
# [23:39:30 INFO]: Loaded 3,106 recipes
# [23:39:39 INFO]: Starting minecraft server version 1.16.5
# [23:39:39 INFO]: Loading properties
# [23:39:39 INFO]: Default game type: SURVIVAL
# [23:39:39 INFO]: Generating keypair
# 1h=> [23:39:39 INFO]: Starting Minecraft server on *:25,565
# [23:39:39 INFO]: Using epoll channel type
# [23:39:39 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [23:39:39 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [23:39:39 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [23:39:39 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [23:39:39 INFO]: This server is running Mohist version 1.16.5-1239 (MC: 1.16.5) (Implementing API version 1.16.5-R0.1-SNAPSHOT, Forge version 36.2.42)
# [23:39:41 INFO]: Debug logging is enabled
# [23:39:41 INFO]: Server Ping Player Sample Count: 12
# [23:39:41 INFO]: Using 4 threads for Netty based IO
# [23:39:41 INFO]: Loaded inheritance map of 2322 classes
# [23:39:41 WARN]: Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [23:39:44 WARN]: Legacy plugin AutoSave v1.0 does not specify an api-version.
# [23:39:44 WARN]: Legacy plugin LuzN v1.1 does not specify an api-version.
# [23:39:44 ERROR]: Could not load 'plugins/FallingOverride-1.18.1-1.0.jar' in folder 'plugins'
# org.bukkit.plugin.InvalidPluginException: Unsupported API version 1.18
# 	at org.bukkit.craftbukkit.v1_16_R3.util.CraftMagicNumbers.checkSupported(CraftMagicNumbers.java:325) ~[forge:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader.loadPlugin(JavaPluginLoader.java:140) ~[forge:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugin(SimplePluginManager.java:393) ~[forge:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugins(SimplePluginManager.java:301) ~[forge:?]
# 	at org.bukkit.craftbukkit.v1_16_R3.CraftServer.loadPlugins(CraftServer.java:393) ~[forge:7e29f765-296df566-9fb885e8]
# 	at net.minecraft.server.dedicated.DedicatedServer.func_71197_b(DedicatedServer.java:218) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.func_240802_v_(MinecraftServer.java:800) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.func_240783_a_(MinecraftServer.java:267) ~[?:?]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# [23:39:44 INFO]: [GSit] Loading GSit v1.7.0
# [23:39:44 INFO]: [AutoSave] Loading AutoSave v1.0
# [23:39:44 INFO]: [AnvilColors] Loading AnvilColors v1.0.4
# [23:39:44 INFO]: [LuzN] Loading LuzN v1.1
# [23:39:44 INFO]: Loading JourneyMap Forge Configs
# [23:39:44 INFO]: Loading JourneyMap Forge Configs
# [23:39:44 INFO]: Preparing level "world"
# [23:39:44 INFO]: Preparing start region for dimension minecraft:overworld
# [23:39:45 INFO]: Preparing spawn area: 0%
# [23:39:46 INFO]: Time elapsed: 1,607 ms
# [23:39:46 INFO]: Preparing start region for dimension minecraft:the_nether
# [23:39:47 INFO]: Time elapsed: 963 ms
# [23:39:47 INFO]: Preparing start region for dimension minecraft:the_end
# [23:39:47 INFO]: Time elapsed: 385 ms
# [23:39:47 INFO]: [GSit] Enabling GSit v1.7.0
# [23:39:47 INFO]: [GSit] The plugin was successfully enabled.
# [23:39:47 INFO]: [AutoSave] Enabling AutoSave v1.0
# [23:39:47 INFO]: [AutoSave] Enable
# [23:39:47 INFO]: [AnvilColors] Enabling AnvilColors v1.0.4
# [23:39:47 INFO]: [LuzN] Enabling LuzN v1.1
# [23:39:47 INFO]: [LuzN] Plugin carregado.
# [23:39:47 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [23:39:47 INFO]: Done (3.586s)! For help, type "help"
# [23:39:48 INFO]: {SPAWN_DRAGON_SKELETON_I_CF=true, HYDRA_CAVE_CF=true, SPAWN_SEA_SERPENT_CF=true, SPAWN_STYMPHALIAN_BIRD_CF=true, SPAWN_WANDERING_CYCLOPS_CF=true, PIXIE_VILLAGE_CF=false, SPAWN_DEATH_WORM_CF=true, FIRE_DRAGON_CAVE_CF=true, SIREN_ISLAND_CF=true, MYRMEX_HIVE_DESERT_CF=true, SPAWN_HIPPOCAMPUS_CF=true, FIRE_DRAGON_ROOST_CF=true, MYRMEX_HIVE_JUNGLE_CF=true, GORGON_TEMPLE_CF=true, COPPER_ORE_CF=true, SILVER_ORE_CF=true, LIGHTNING_DRAGON_CAVE_CF=true, SPAWN_DRAGON_SKELETON_F_CF=true, AMETHYST_ORE_CF=true, SPAWN_DRAGON_SKELETON_L_CF=true, LIGHTNING_LILY_CF=true, MAUSOLEUM_CF=true, ICE_DRAGON_CAVE_CF=true, GRAVEYARD_CF=true, SAPPHIRE_ORE_CF=true, LIGHTNING_DRAGON_ROOST_CF=true, CYCLOPS_CAVE_CF=true, FROST_LILY_CF=true, FIRE_LILY_CF=true, ICE_DRAGON_ROOST_CF=true}
# [23:39:48 INFO]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=true, TROLL_F=true}
# [23:39:48 WARN]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [23:39:48 INFO]: [voicechat] Voice host is 'self-pot.gl.at.ply.gg'
# [23:39:48 INFO]:
# [23:39:48 INFO]: ------------------------
# [23:39:48 INFO]: Server is saved ...
# [23:39:48 WARN]: A manual (plugin-induced) save has been detected while server is configured to auto-save. This may affect performance.
# [23:39:48 INFO]: [voicechat] Voice chat server started at port 2650
# [23:39:49 INFO]: Successfully saved.
# [23:39:49 INFO]: ------------------------
# [23:39:49 INFO]:
# [23:40:04 INFO]: UUID of player PaoDeQueijoWD is 7f28f8a6-a297-3229-9ff3-48126299256f
# [23:40:04 INFO]: Client attempting to join with 46 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, tlskincape, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:40:11 INFO]: PaoDeQueijoWD[/127.22.240.231:45337] logged in with entity id 241 at (-501.355, 64, -236.921)
# [23:40:12 INFO]: [voicechat] Received secret request of PaoDeQueijoWD (18)
# [23:40:12 INFO]: [voicechat] Sent secret to PaoDeQueijoWD
# [23:40:15 INFO]: UUID of player CnrUWU is cd000d24-31d9-397e-bf5d-a68da682d44e
# [23:40:15 INFO]: Client attempting to join with 46 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, tlskincape, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:40:18 INFO]: [voicechat] Successfully authenticated player 7f28f8a6-a297-3229-9ff3-48126299256f
# [23:40:19 INFO]: CnrUWU[/127.215.134.103:41889] logged in with entity id 484 at (132.18, 63.032, 64.474)
# [23:40:19 INFO]: [voicechat] Successfully validated connection of player 7f28f8a6-a297-3229-9ff3-48126299256f
# [23:40:19 INFO]: [voicechat] Player PaoDeQueijoWD (7f28f8a6-a297-3229-9ff3-48126299256f) successfully connected to voice chat
# [23:40:19 INFO]: [voicechat] Received secret request of CnrUWU (18)
# [23:40:19 INFO]: [voicechat] Sent secret to CnrUWU
# [23:40:23 INFO]: [voicechat] Successfully authenticated player cd000d24-31d9-397e-bf5d-a68da682d44e
# [23:40:24 INFO]: [voicechat] Successfully validated connection of player cd000d24-31d9-397e-bf5d-a68da682d44e
# [23:40:24 INFO]: [voicechat] Player CnrUWU (cd000d24-31d9-397e-bf5d-a68da682d44e) successfully connected to voice chat
# [23:40:42 INFO]: UUID of player Harry_Porra_ is c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [23:40:42 INFO]: Client attempting to join with 45 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:40:46 INFO]: Harry_Porra_[/127.179.236.167:46537] logged in with entity id 1,174 at (-945.997, 71, -277.081)
# [23:40:47 INFO]: [voicechat] Received secret request of Harry_Porra_ (18)
# [23:40:47 INFO]: [voicechat] Sent secret to Harry_Porra_
# [23:40:55 INFO]: [voicechat] Successfully authenticated player c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [23:40:56 INFO]: [voicechat] Successfully validated connection of player c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [23:40:56 INFO]: [voicechat] Player Harry_Porra_ (c8ef2a6a-7ab8-39b6-8136-f287916e008e) successfully connected to voice chat
# [23:42:25 INFO]: UUID of player Duck1201 is b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:42:25 INFO]: Client attempting to join with 46 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, customskinloader, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:42:31 INFO]: Duck1201[/127.88.73.139:60997] logged in with entity id 2,230 at (-132.3, 67, -56.3)
# [23:42:33 INFO]: [voicechat] Received secret request of Duck1201 (18)
# [23:42:33 INFO]: [voicechat] Sent secret to Duck1201
# [23:42:43 INFO]: [voicechat] Successfully authenticated player b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:42:44 INFO]: [voicechat] Successfully validated connection of player b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:42:44 INFO]: [voicechat] Player Duck1201 (b26f9a7a-70fd-3cd3-887b-7710affad4db) successfully connected to voice chat
# [23:42:52 INFO]: UUID of player lk is bcc874e1-416a-3910-97a6-09d345d72298
# [23:42:53 INFO]: Client attempting to join with 45 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, tlskincape, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:43:00 INFO]: lk[/127.199.44.249:45613] logged in with entity id 2,432 at (-990.646, 12, -339.11)
# [23:43:04 INFO]: [voicechat] Received secret request of lk (18)
# [23:43:04 INFO]: [voicechat] Sent secret to lk
# [23:43:16 INFO]: [voicechat] Successfully authenticated player bcc874e1-416a-3910-97a6-09d345d72298
# [23:43:17 INFO]: [voicechat] Successfully validated connection of player bcc874e1-416a-3910-97a6-09d345d72298
# [23:43:17 INFO]: [voicechat] Player lk (bcc874e1-416a-3910-97a6-09d345d72298) successfully connected to voice chat
# [23:43:56 INFO]: Duck1201 issued server command: /op l
# [23:43:56 INFO]: [Duck1201: Made l a server operator]
# [23:43:58 INFO]: Duck1201 issued server command: /op lk
# [23:43:58 INFO]: [Duck1201: Made lk a server operator]
# [23:44:01 INFO]: Duck1201 issued server command: /op Harry_Porra_
# [23:44:01 INFO]: [Duck1201: Made Harry_Porra_ a server operator]
# [23:44:03 INFO]: Duck1201 issued server command: /op PaoDeQueijoWD
# [23:44:03 INFO]: [Duck1201: Made PaoDeQueijoWD a server operator]
# [23:44:05 INFO]: Duck1201 issued server command: /op C
# [23:44:05 INFO]: [Duck1201: Made C a server operator]
# [23:44:06 INFO]: Duck1201 issued server command: /op CnrUWU
# [23:44:06 INFO]: [Duck1201: Made CnrUWU a server operator]
# [23:44:49 INFO]:
# [23:44:49 INFO]: ------------------------
# [23:44:49 INFO]: Server is saved ...
# [23:44:49 INFO]: >> Novo mundo
# [23:44:49 INFO]: >> Novo mundo
# [23:44:49 INFO]: >> Novo mundo
# [23:44:49 INFO]: >> Novo mundo
# [23:44:49 INFO]: >> Novo mundo
# [23:44:49 INFO]: >> DIM-1
# [23:44:49 INFO]: >> DIM-1
# [23:44:49 INFO]: >> DIM-1
# [23:44:49 INFO]: >> DIM-1
# [23:44:49 INFO]: >> DIM-1
# [23:44:49 INFO]: >> DIM1
# [23:44:49 INFO]: >> DIM1
# [23:44:49 INFO]: >> DIM1
# [23:44:49 INFO]: >> DIM1
# [23:44:49 INFO]: >> DIM1
# [23:44:49 INFO]: Successfully saved.
# [23:44:49 INFO]: ------------------------
# [23:44:49 INFO]:
# [23:45:16 INFO]: Duck1201 lost connection: Disconnected
# [23:45:16 INFO]: [voicechat] Disconnecting client Duck1201
# [23:45:16 INFO]: Duck1201 left the game
# [23:45:35 INFO]: UUID of player Duck1201 is b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:45:35 INFO]: Client attempting to join with 46 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, customskinloader, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:45:36 INFO]: <lk> TA TD DE BOA?
# [23:45:41 INFO]: Duck1201[/127.88.73.139:56585] logged in with entity id 3,750 at (-114.7, 70.562, -67.7)
# [23:45:42 INFO]: [voicechat] Received secret request of Duck1201 (18)
# [23:45:42 INFO]: [voicechat] Sent secret to Duck1201
# [23:45:50 INFO]: [voicechat] Successfully authenticated player b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:45:51 INFO]: [voicechat] Successfully validated connection of player b26f9a7a-70fd-3cd3-887b-7710affad4db
# [23:45:51 INFO]: [voicechat] Player Duck1201 (b26f9a7a-70fd-3cd3-887b-7710affad4db) successfully connected to voice chat
# [23:46:43 INFO]: lk has made the advancement [Diamonds!]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:49:48 INFO]:
# [23:49:48 INFO]: ------------------------
# [23:49:48 INFO]: Server is saved ...
# [23:49:48 INFO]: >> Novo mundo
# [23:49:48 INFO]: >> Novo mundo
# [23:49:48 INFO]: >> Novo mundo
# [23:49:48 INFO]: >> Novo mundo
# [23:49:48 INFO]: >> Novo mundo
# [23:49:48 INFO]: >> DIM-1
# [23:49:48 INFO]: >> DIM-1
# [23:49:48 INFO]: >> DIM-1
# [23:49:48 INFO]: >> DIM-1
# [23:49:48 INFO]: >> DIM-1
# [23:49:48 INFO]: >> DIM1
# [23:49:48 INFO]: >> DIM1
# [23:49:48 INFO]: >> DIM1
# [23:49:48 INFO]: >> DIM1
# [23:49:48 INFO]: >> DIM1
# [23:49:48 INFO]: Successfully saved.
# [23:49:48 INFO]: ------------------------
# [23:49:48 INFO]:
# [23:49:52 INFO]: <Duck1201> aa
# [23:49:58 INFO]: Duck1201 issued server command: /tps
# [23:54:48 INFO]:
# [23:54:48 INFO]: ------------------------
# [23:54:48 INFO]: Server is saved ...
# [23:54:48 INFO]: >> Novo mundo
# [23:54:48 INFO]: >> Novo mundo
# [23:54:48 INFO]: >> Novo mundo
# [23:54:48 INFO]: >> Novo mundo
# [23:54:48 INFO]: >> Novo mundo
# [23:54:48 INFO]: >> DIM-1
# [23:54:48 INFO]: >> DIM-1
# [23:54:48 INFO]: >> DIM-1
# [23:54:48 INFO]: >> DIM-1
# [23:54:48 INFO]: >> DIM-1
# [23:54:48 INFO]: >> DIM1
# [23:54:48 INFO]: >> DIM1
# [23:54:48 INFO]: >> DIM1
# [23:54:48 INFO]: >> DIM1
# [23:54:48 INFO]: >> DIM1
# [23:54:48 INFO]: Successfully saved.
# [23:54:48 INFO]: ------------------------
# [23:54:48 INFO]:
# [23:55:08 INFO]: Harry_Porra_ was slain by Zombie
# [23:56:43 INFO]: UUID of player _Sunakku is e71f6422-2f65-3b80-921e-d49d75186929
# [23:56:43 INFO]: Client attempting to join with 44 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [23:56:48 INFO]: _Sunakku[/127.135.12.180:55889] logged in with entity id 11,001 at (-201.5, 64, -85.5)
# [23:56:48 INFO]: _Sunakku has made the advancement [Ice and Fire]
# [23:56:48 INFO]: _Sunakku has made the advancement [Rats]
# [23:56:50 INFO]: [voicechat] Received secret request of _Sunakku (18)
# [23:56:50 INFO]: [voicechat] Sent secret to _Sunakku
# [23:56:59 INFO]: [voicechat] Successfully authenticated player e71f6422-2f65-3b80-921e-d49d75186929
# [23:57:00 INFO]: [voicechat] Successfully validated connection of player e71f6422-2f65-3b80-921e-d49d75186929
# [23:57:00 INFO]: [voicechat] Player _Sunakku (e71f6422-2f65-3b80-921e-d49d75186929) successfully connected to voice chat
# [23:57:01 INFO]: <Duck1201> julia
# [23:57:03 INFO]: <Duck1201> maravilhosa
# [23:57:06 INFO]: <Duck1201> mim de seu livro
# [23:57:07 INFO]: Harry_Porra_ issued server command: /LUZ
# [23:57:08 INFO]: <Duck1201> dos animal
# [23:57:09 INFO]: <Duck1201> pls
# [23:57:11 INFO]: Harry_Porra_ issued server command: /lu
# [23:57:16 INFO]: Harry_Porra_ issued server command: /luz
# [23:57:36 INFO]: <Duck1201> desmuta o mic ae
# [23:57:51 INFO]: <_Sunakku> pq ce tem um rato?
# [23:57:56 INFO]: <Duck1201> eu sou o rei dos ratos
# [23:58:02 INFO]: <Duck1201> clica V
# [23:58:05 INFO]: <Duck1201> para arrumar o mic
# [23:58:22 INFO]: <Harry_Porra_> O MLK BURRO DO KRL
# [23:58:25 INFO]: <CnrUWU> ??
# [23:58:27 INFO]: <Harry_Porra_> o cara boto senha
# [23:58:34 INFO]: <CnrUWU> Td mundo saiu e foi pra um grupo privado?
# [23:58:39 INFO]: <CnrUWU> Quanta viadagem
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:58:42 INFO]: <Harry_Porra_> n sei
# [23:59:10 INFO]: <lk> pato
# [23:59:12 INFO]: <lk> da op p ela
# [23:59:14 INFO]: <Duck1201> oi?
# [23:59:14 INFO]: CnrUWU was blown up by Creeper
# [23:59:15 INFO]: <Duck1201> vdd
# [23:59:18 INFO]: Duck1201 issued server command: /op _Sunakku
# [23:59:18 INFO]: [Duck1201: Made _Sunakku a server operator]
# [23:59:31 INFO]: Harry_Porra_ lost connection: Disconnected
# [23:59:31 INFO]: [voicechat] Disconnecting client Harry_Porra_
# [23:59:31 INFO]: Harry_Porra_ left the game
# [23:59:48 INFO]:
# [23:59:48 INFO]: ------------------------
# [23:59:48 INFO]: Server is saved ...
# [23:59:48 INFO]: >> Novo mundo
# [23:59:48 INFO]: >> Novo mundo
# [23:59:48 INFO]: >> Novo mundo
# [23:59:48 INFO]: >> Novo mundo
# [23:59:48 INFO]: >> Novo mundo
# [23:59:48 INFO]: >> DIM-1
# [23:59:48 INFO]: >> DIM-1
# [23:59:48 INFO]: >> DIM-1
# [23:59:48 INFO]: >> DIM-1
# [23:59:48 INFO]: >> DIM-1
# [23:59:48 INFO]: >> DIM1
# [23:59:48 INFO]: >> DIM1
# [23:59:48 INFO]: >> DIM1
# [23:59:48 INFO]: >> DIM1
# [23:59:48 INFO]: >> DIM1
# [23:59:48 INFO]: Successfully saved.
# [23:59:48 INFO]: ------------------------
# [23:59:48 INFO]:
# [23:59:49 INFO]: CnrUWU was shot by Skeleton
# [23:59:59 INFO]: UUID of player Harry_Porra_ is c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [23:59:59 INFO]: Client attempting to join with 45 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, fallingleaves, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [00:00:03 INFO]: Harry_Porra_[/127.179.236.167:44921] logged in with entity id 12,988 at (-706.638, 38, -50.143)
# [00:00:04 INFO]: [voicechat] Received secret request of Harry_Porra_ (18)
# [00:00:04 INFO]: [voicechat] Sent secret to Harry_Porra_
# [00:00:11 INFO]: [voicechat] Successfully authenticated player c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [00:00:12 INFO]: [voicechat] Successfully validated connection of player c8ef2a6a-7ab8-39b6-8136-f287916e008e
# [00:00:12 INFO]: [voicechat] Player Harry_Porra_ (c8ef2a6a-7ab8-39b6-8136-f287916e008e) successfully connected to voice chat
# [00:00:53 INFO]: CnrUWU was shot by Skeleton
# [00:03:32 INFO]: <Duck1201> empresta o livro ae
# [00:04:02 WARN]: Configuration error when parsing "botania:terra_axe": qualifier string \"botania:terra_axe\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "mekanism:atomic_disassembler": qualifier string \"mekanism:atomic_disassembler\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "@lumberjack": qualifier string \"@lumberjack\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "@lumberjack": no items found in namespace "lumberjack"
# [00:04:02 WARN]: Configuration error when parsing "practicaltools:iron_greataxe": qualifier string \"practicaltools:iron_greataxe\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "practicaltools:golden_greataxe": qualifier string \"practicaltools:golden_greataxe\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "practicaltools:diamond_greataxe": qualifier string \"practicaltools:diamond_greataxe\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "practicaltools:netherite_greataxe": qualifier string \"practicaltools:netherite_greataxe\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "#tconstruct:modifiable/harvest": qualifier string \"#tconstruct:modifiable/harvest\" is malformed
# [00:04:02 WARN]: Configuration error when parsing "#tconstruct:modifiable/harvest": item tag "tconstruct" does not exist
# [00:04:48 INFO]:
# [00:04:48 INFO]: ------------------------
# [00:04:48 INFO]: Server is saved ...
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> Novo mundo
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM-1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: >> DIM1
# [00:04:48 INFO]: Successfully saved.
# [00:04:48 INFO]: ------------------------
# [00:04:48 INFO]:
# [00:07:12 INFO]: Duck1201 issued server command: /give @a alexsmobs:animal_dictionary 1
# [00:07:12 INFO]: [Duck1201: Gave 1 [Animal Dictionary] to 6]
# [00:07:13 INFO]: Harry_Porra_ was slain by Zombie
# [00:07:17 INFO]: <lk> ?????????
# [00:07:20 INFO]: <lk> q porra é essa
# [00:07:25 INFO]: <lk> virou bagunça, vsf
# [00:07:27 INFO]: <Duck1201> dicionario
# [00:07:28 INFO]: <PaoDeQueijoWD> ?
# [00:07:30 INFO]: <Duck1201> dos animal
# [00:07:32 INFO]: <Duck1201> ué
# [00:07:35 INFO]: <PaoDeQueijoWD> vc é burro?
# [00:07:41 INFO]: [voicechat] Player cd000d24-31d9-397e-bf5d-a68da682d44e timed out
# [00:07:41 INFO]: [voicechat] Reconnecting player CnrUWU
# [00:07:41 INFO]: [voicechat] Sent secret to CnrUWU
# [00:07:41 INFO]: <lk> a vd é um morango?
# [00:07:43 INFO]: [voicechat] Successfully authenticated player cd000d24-31d9-397e-bf5d-a68da682d44e
# [00:07:44 INFO]: [voicechat] Successfully validated connection of player cd000d24-31d9-397e-bf5d-a68da682d44e
# [00:07:44 INFO]: [voicechat] Player CnrUWU (cd000d24-31d9-397e-bf5d-a68da682d44e) successfully connected to voice chat
# [00:07:53 INFO]: <PaoDeQueijoWD> é literalmente um item q vc nasce junto
# [00:07:57 INFO]: <lk> fds?
# [00:08:02 INFO]: <PaoDeQueijoWD> desfodase
# [00:08:13 INFO]: <lk> bglh é craftavel, sem contar q ele só n tem pq morreu com
# [00:08:25 INFO]: <PaoDeQueijoWD> Bem, eu não perdi o meu
# [00:08:26 INFO]: <Harry_Porra_> vai toma no cu oc
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:09:48 INFO]:
# [00:09:48 INFO]: ------------------------
# [00:09:48 INFO]: Server is saved ...
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> Novo mundo
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM-1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: >> DIM1
# [00:09:48 INFO]: Successfully saved.
# [00:09:48 INFO]: ------------------------
# [00:09:48 INFO]:
# [00:10:44 INFO]: <Duck1201> &
# [00:11:51 INFO]: Duck1201 issued server command: /tps
# [00:12:06 INFO]: CnrUWU issued server command: /tps
# [00:12:22 INFO]: _Sunakku has made the advancement [Acquire Hardware]
# [00:12:38 INFO]: _Sunakku has made the advancement [Suit Up]
# [00:13:14 INFO]: lk issued server command: /tell _Sunakku me ouva?
# [00:13:31 INFO]: <_Sunakku> si
# [00:13:42 INFO]: <lk> vem ca ent
# [00:14:03 INFO]: <lk> falta 1
# [00:14:24 INFO]: _Sunakku has made the advancement [Isn't It Iron Pick]
# [00:14:48 INFO]:
# [00:14:48 INFO]: ------------------------
# [00:14:48 INFO]: Server is saved ...
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> Novo mundo
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM-1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: >> DIM1
# [00:14:48 INFO]: Successfully saved.
# [00:14:48 INFO]: ------------------------
# [00:14:48 INFO]:
# [00:15:13 INFO]: lk issued server command: /tell _Sunakku calmo, só vamos esperar as coisas cozinharem e vamos embora
# [00:15:33 INFO]: PaoDeQueijoWD has made the advancement [Hunt and Gather]
# [00:15:55 INFO]: <lk> slg
# [00:16:19 INFO]: <lk> midia
# [00:16:30 INFO]: <CnrUWU> Meu mano Black, n sei se tu tlg, mas ta com o plugin de /luz
# [00:16:42 INFO]: _Sunakku has made the advancement [Stone Age]
# [00:16:52 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:52 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:53 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:53 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:53 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:53 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:54 WARN]: PaoDeQueijoWD moved wrongly!
# [00:16:54 WARN]: PaoDeQueijoWD moved wrongly!
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:18:59 INFO]: <lk> oooooomg
# [00:19:04 INFO]: lk issued server command: /luz
# [00:19:16 INFO]: <lk> vamos passar umas aranha
# [00:19:48 INFO]:
# [00:19:48 INFO]: ------------------------
# [00:19:48 INFO]: Server is saved ...
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> Novo mundo
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM-1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: >> DIM1
# [00:19:48 INFO]: Successfully saved.
# [00:19:48 INFO]: ------------------------
# [00:19:48 INFO]:
# [00:20:58 INFO]: _Sunakku has made the advancement [Monster Hunter]
# [00:21:52 INFO]: Harry_Porra_ was slain by Zombie
# [00:24:18 INFO]: <PaoDeQueijoWD> zzz
# [00:24:20 INFO]: <PaoDeQueijoWD> zzzz
# [00:24:48 INFO]:
# [00:24:48 INFO]: ------------------------
# [00:24:48 INFO]: Server is saved ...
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> Novo mundo
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM-1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: >> DIM1
# [00:24:48 INFO]: Successfully saved.
# [00:24:48 INFO]: ------------------------
# [00:24:48 INFO]:
# [00:24:53 INFO]: Duck1201 was slain by Phantom
# [00:25:17 INFO]: <lk> vamo embora
# [00:25:18 INFO]: <lk> vem
# [00:26:40 INFO]: lk issued server command: /tell _Sunakku vc me ouve?
# [00:26:49 INFO]: Duck1201 issued server command: /reload
# [00:26:49 INFO]: Duck1201: Please note that this command is not supported and may cause issues when using some plugins.
# [00:26:49 INFO]: Duck1201: If you encounter any issues please use the /stop command to restart your server.
# [00:26:49 WARN]: For your server security, Bukkit reloading is not supported by Mohist.
# [00:26:49 INFO]: Duck1201: Reload complete.
# [00:26:53 INFO]: <Duck1201> ..
# [00:26:54 INFO]: <_Sunakku> no
# [00:26:54 INFO]: Duck1201 issued server command: /pl
# [00:28:08 INFO]: <Duck1201> aa[
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:29:40 INFO]: <lk> MEEE
# [00:29:44 INFO]: <lk> eu to mtt bugado
# [00:29:48 INFO]:
# [00:29:48 INFO]: ------------------------
# [00:29:48 INFO]: Server is saved ...
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> Novo mundo
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM-1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: >> DIM1
# [00:29:48 INFO]: Successfully saved.
# [00:29:48 INFO]: ------------------------
# [00:29:48 INFO]:
# [00:30:01 INFO]: _Sunakku has made the advancement [Crops of the Wild]
# [00:31:12 INFO]: <lk> ss
# [00:31:13 INFO]: <lk> ss
# [00:31:40 INFO]: <lk> nao
# [00:31:48 INFO]: <lk> sou eu q to só o ouro
# [00:31:50 INFO]: <lk> calmae
# [00:31:51 INFO]: lk lost connection: Disconnected
# [00:31:51 INFO]: [voicechat] Disconnecting client lk
# [00:31:51 INFO]: lk left the game
# [00:32:11 INFO]: UUID of player lk is bcc874e1-416a-3910-97a6-09d345d72298
# [00:32:11 INFO]: Client attempting to join with 45 mods : minecraft, mcwbridges, farmersdelight, grapplemod, treechop, skyvillages, voicechat, ambientsounds, biomesoplenty, creativecore, jei, cavesandcliffs, abnormals_core, mcwwindows, torohealth, flywheel, create, waystones, skylands, shutupexperimentalsettings, journeymap, citadel, alexsmobs, rats, securitycraft, parcool, naturescompass, sereneseasons, otg, buildersaddition, sophisticatedbackpacks, cavebiomeapi, nethers_delight, iceandfire, cloth-config, forge, appleskin, dummmmmmy, tlskincape, supplementaries, dsurround, sndctrl, environs, mobeffects, selene
# [00:32:17 INFO]: lk[/127.199.44.249:54527] logged in with entity id 34,353 at (-575.432, 71, -318.629)
# [00:32:18 INFO]: [voicechat] Received secret request of lk (18)
# [00:32:18 INFO]: [voicechat] Sent secret to lk
# [00:32:26 INFO]: [voicechat] Successfully authenticated player bcc874e1-416a-3910-97a6-09d345d72298
# [00:32:27 INFO]: [voicechat] Successfully validated connection of player bcc874e1-416a-3910-97a6-09d345d72298
# [00:32:27 INFO]: [voicechat] Player lk (bcc874e1-416a-3910-97a6-09d345d72298) successfully connected to voice chat
# [00:33:11 INFO]: <lk> msm senha
# [00:33:13 INFO]: <lk> tentae
# [00:33:30 INFO]: lk issued server command: /luz
# [00:34:49 INFO]:
# [00:34:49 INFO]: ------------------------
# [00:34:49 INFO]: Server is saved ...
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> Novo mundo
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM-1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: >> DIM1
# [00:34:49 INFO]: Successfully saved.
# [00:34:49 INFO]: ------------------------
# [00:34:49 INFO]:
# [00:37:02 INFO]: PaoDeQueijoWD has made the advancement [Crops of the Wild]
# [00:37:20 INFO]: PaoDeQueijoWD has made the advancement [Mine? Mine? Mine?]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:39:12 INFO]: <lk> ta mais gostosinho
# [00:39:22 INFO]: <lk> só esperae q minha coroa apareceu aq no quarto, 2p
# [00:39:24 INFO]: <lk> claro q da
# [00:39:25 INFO]: <PaoDeQueijoWD> ?
# [00:39:27 INFO]: <lk> mas ai vai da sua vtd
# [00:39:27 INFO]: <CnrUWU> ?
# [00:39:28 INFO]: <Duck1201> ?
# [00:39:32 INFO]: <lk> entrosas
# [00:39:49 INFO]:
# [00:39:49 INFO]: ------------------------
# [00:39:49 INFO]: Server is saved ...
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> Novo mundo
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM-1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: >> DIM1
# [00:39:49 INFO]: Successfully saved.
# [00:39:49 INFO]: ------------------------
# [00:39:49 INFO]:
# [00:41:03 INFO]: <lk> linde
# [00:41:06 INFO]: <lk> reflexo
# [00:41:37 INFO]: Duck1201 has reached the goal [The Copper Age]
# [00:41:59 INFO]: <_Sunakku> quem se mexer é petista
# [00:43:02 INFO]: CnrUWU has made the advancement [Cover Me With Diamonds]
# [00:44:49 INFO]:
# [00:44:49 INFO]: ------------------------
# [00:44:49 INFO]: Server is saved ...
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> Novo mundo
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM-1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: >> DIM1
# [00:44:49 INFO]: Successfully saved.
# [00:44:49 INFO]: ------------------------
# [00:44:49 INFO]:
# [00:46:53 INFO]: Harry_Porra_ lost connection: Disconnected
# [00:46:53 INFO]: [voicechat] Disconnecting client Harry_Porra_
# [00:46:53 INFO]: Harry_Porra_ left the game
# [00:48:31 INFO]: CnrUWU has made the advancement [The Parrots and the Bats]
# [00:48:37 INFO]: Duck1201 issued server command: /luz on
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:49:49 INFO]:
# [00:49:49 INFO]: ------------------------
# [00:49:49 INFO]: Server is saved ...
# [00:49:49 INFO]: >> Novo mundo
# [00:49:49 INFO]: >> Novo mundo
# [00:49:49 INFO]: >> Novo mundo
# [00:49:49 INFO]: >> Novo mundo
# [00:49:49 INFO]: >> Novo mundo
# [00:49:49 INFO]: >> DIM-1
# [00:49:49 INFO]: >> DIM-1
# [00:49:49 INFO]: >> DIM-1
# [00:49:49 INFO]: >> DIM-1
# [00:49:49 INFO]: >> DIM-1
# [00:49:49 INFO]: >> DIM1
# [00:49:49 INFO]: >> DIM1
# [00:49:49 INFO]: >> DIM1
# [00:49:49 INFO]: >> DIM1
# [00:49:49 INFO]: >> DIM1
# [00:49:49 INFO]: Successfully saved.
# [00:49:49 INFO]: ------------------------
# [00:49:49 INFO]:
# [00:51:00 WARN]: lk moved wrongly!
# [00:51:26 WARN]: Entity ServerPlayerEntity['CnrUWU'/484, l='ServerLevel[Novo mundo]', x=234.50, y=65.00, z=-448.50](TextComponent{text='CnrUWU', siblings=[], style=Style{ color=null, bold=null, italic=null, underlined=null, strikethrough=null, obfuscated=null, clickEvent=null, hoverEvent=null, insertion=null, font=minecraft:default}} at 234.5,65.0,-448.5) left loaded chunk area
# [00:52:53 INFO]: <lk> cade o gordo?
# [00:52:56 INFO]: <PaoDeQueijoWD> sla
# [00:52:58 INFO]: <PaoDeQueijoWD> saiu
# [00:53:03 INFO]: <lk> ralou fortao?
# [00:53:15 INFO]: <PaoDeQueijoWD> ele foi falar com a avó
# [00:53:21 INFO]: <PaoDeQueijoWD> ai saiu um tempo dps
# [00:53:26 INFO]: <lk> moiado
# [00:53:30 INFO]: _Sunakku issued server command: /skin
# [00:53:33 INFO]: <lk> esse neguinho é caozeiro, só volta amanha
# [00:54:05 INFO]: <lk> tiraram o /skin?
# [00:54:12 INFO]: <PaoDeQueijoWD> s
# [00:54:17 INFO]: <PaoDeQueijoWD> se n o parkour n ia funfar
# [00:54:39 WARN]: Tried to load a DUMMY block entity @ BlockPos{x=-1683, y=20, z=-608} but found not block entity block Block{minecraft:stone} at location
# [00:54:49 WARN]: Tried to load a DUMMY block entity @ BlockPos{x=-1753, y=21, z=-587} but found not block entity block Block{minecraft:stone} at location
# [00:54:49 WARN]: Tried to load a DUMMY block entity @ BlockPos{x=-1750, y=21, z=-588} but found not block entity block Block{minecraft:stone} at location
# [00:54:49 INFO]:
# [00:54:49 INFO]: ------------------------
# [00:54:49 INFO]: Server is saved ...
# [00:54:49 INFO]: >> Novo mundo
# [00:54:49 INFO]: >> Novo mundo
# [00:54:49 INFO]: >> Novo mundo
# [00:54:49 INFO]: >> Novo mundo
# [00:54:49 INFO]: >> Novo mundo
# [00:54:49 INFO]: >> DIM-1
# [00:54:49 INFO]: >> DIM-1
# [00:54:49 INFO]: >> DIM-1
# [00:54:49 INFO]: >> DIM-1
# [00:54:49 INFO]: >> DIM-1
# [00:54:49 INFO]: >> DIM1
# [00:54:49 INFO]: >> DIM1
# [00:54:49 INFO]: >> DIM1
# [00:54:49 INFO]: >> DIM1
# [00:54:49 INFO]: >> DIM1
# [00:54:49 INFO]: Successfully saved.
# [00:54:49 INFO]: ------------------------
# [00:54:49 INFO]:
# >
